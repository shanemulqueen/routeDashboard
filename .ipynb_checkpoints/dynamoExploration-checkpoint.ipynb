# %%
import folium
import boto3
from boto3.dynamodb.conditions import Key, Attr
import json
import decimal
import pandas as pd
import numpy as np
from collections import defaultdict

from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %%
client = boto3.client('dynamodb', region_name='us-east-1')

# %%
dynamodb = boto3.resource('dynamodb', region_name='us-east-1')
table = dynamodb.Table('Books')

# %%
with table.batch_writer() as batch:
    batch.put_item(Item={"Author": "John Grisham", "Title": "The Rainmaker",
        "Category": "Suspense", "Formats": { "Hardcover": "J4SUKVGU", "Paperback": "D7YF4FCX" } })
    batch.put_item(Item={"Author": "John Grisham", "Title": "The Firm",
        "Category": "Suspense", "Formats": { "Hardcover": "Q7QWE3U2",
        "Paperback": "ZVZAYY4F", "Audiobook": "DJ9KS9NM" } })
    batch.put_item(Item={"Author": "James Patterson", "Title": "Along Came a Spider",
        "Category": "Suspense", "Formats": { "Hardcover": "C9NR6RJ7",
        "Paperback": "37JVGDZG", "Audiobook": "6348WX3U" } })
    batch.put_item(Item={"Author": "Dr. Seuss", "Title": "Green Eggs and Ham",
        "Category": "Children", "Formats": { "Hardcover": "GVJZQ7JK",
        "Paperback": "A4TFUR98", "Audiobook": "XWMGHW96" } })
    batch.put_item(Item={"Author": "William Shakespeare", "Title": "Hamlet",
        "Category": "Drama", "Formats": { "Hardcover": "GVJZQ7JK",
        "Paperback": "A4TFUR98", "Audiobook": "XWMGHW96" } })

# %%
resp = table.get_item(Key={"Author": "John Grisham", "Title": "The Rainmaker"})

print(resp['Item'])
# Out:
# {'Title': 'The Rainmaker', 'Formats': {'Hardcover': 'J4SUKVGU', 'Paperback': 'D7YF4FCX'}, 'Author': 'John Grisham', 'Category': 'Suspense'}

# %%
session = boto3.Session(profile_name='fleeting')

# %%
client = boto3.client('dynamodb', region_name='us-east-2')

# %%
dynamodb = boto3.resource('dynamodb', region_name='us-east-2')
for tab in client.list_tables()['TableNames']:
    table = dynamodb.Table(tab)
    resp = table.scan()
    print("{}: {}".format(tab, len(resp['Items'])))
# Out:
# carrier: 2
# dispatch_instruction: 2
# driver: 1
# experience: 0
# job: 6
# job_detail: 6
# job_favourite: 0
# job_status: 10
# job_task: 14
# job_type: 2
# password_reset_token: 0
# reference: 0
# residency: 0
# user: 4
# user_status: 3
# user_type: 3
# violation: 0

# %%
table = dynamodb.Table('user')
resp = table.scan()
for elem in resp['Items']:
    try:
        print(elem)
    except:
        print('ERRRORRRR')
# Out:
# {'created_dt': Decimal('1560526144245'), 'password': '$2a$08$N1J9sHzlY3/iejcm.4iqUeQ/IEdwrPl0rtX/fOmt/WX0E4OF/ftdm', 'modified_dt': Decimal('1560526144245'), 'status': Decimal('1'), 'is_active': True, 'screening_completed': False, 'id': '24645580-8eb9-11e9-b024-39da2a204b63', 'email': 'admin@fleetingpro.com', 'type': Decimal('1')}
# {'created_dt': Decimal('1560781785303'), 'password': '$2a$08$KKo0f1NRZ04Hd9Pa4DY5S.4cXRFdq.XltcaVDAxBIAo8hHfS/qjg2', 'modified_dt': Decimal('1560781785304'), 'status': Decimal('1'), 'is_active': True, 'screening_completed': False, 'id': '5a53d7b0-910c-11e9-8b96-e98f1cc1ebcb', 'email': 'bob@carrier.com', 'name': 'Bob Smith', 'type': Decimal('3')}
# {'created_dt': Decimal('1560525583860'), 'profile_image': 'd65cb4f0-8eb7-11e9-b024-39da2a204b63_profile.png', 'modified_dt': Decimal('1560525620432'), 'password': '$2a$08$lG/sIlAjEsliuX1q5fpEsO2FxEiMo2SIFjpT1w/8vK6JCM8m3pAOq', 'status': Decimal('1'), 'address': '123 Main Street', 'is_active': True, 'email': 'test-carrier@fleetingpro.com', 'id': 'd65cb4f0-8eb7-11e9-b024-39da2a204b63', 'screening_completed': True, 'name': 'Test Carrier', 'type': Decimal('3')}
# {'created_dt': Decimal('1560784345053'), 'password': '$2a$08$D9iPSSzWXzyoIEI4rjYF.ep3BFhiQlANRH6gUV6XcRusAmnr43Say', 'modified_dt': Decimal('1560784345053'), 'status': Decimal('1'), 'is_active': True, 'screening_completed': False, 'id': '50114a20-9112-11e9-8b96-e98f1cc1ebcb', 'email': 'bob@gmail.com', 'name': 'Bob Smith', 'type': Decimal('2')}

# %%
table = dynamodb.Table('job')
resp = table.scan()
for elem in resp['Items']:
    try:
        print(elem)
    except:
        print('ERRRORRRR')
# Out:
# {'created_dt': Decimal('1560545816523'), 'load_id': '1231231231', 'modified_dt': Decimal('1560545816523'), 'created_by': 'd65cb4f0-8eb7-11e9-b024-39da2a204b63', 'end_dt': Decimal('1561064115000'), 'special_instructions': 'none', 'start_dt': Decimal('1561064115000'), 'user_id': 'd65cb4f0-8eb7-11e9-b024-39da2a204b63', 'is_active': True, 'description': 'Driving', 'id': 'f20029b0-8ee6-11e9-8c1d-9de473423f0e', 'job_type': Decimal('1'), 'title': 'Driving', 'job_status': Decimal('1')}
# {'created_dt': Decimal('1560538015349'), 'load_id': 'Test load', 'modified_dt': Decimal('1560538015349'), 'created_by': 'd65cb4f0-8eb7-11e9-b024-39da2a204b63', 'end_dt': Decimal('1560537945728'), 'special_instructions': 'None', 'start_dt': Decimal('1560537945728'), 'user_id': 'd65cb4f0-8eb7-11e9-b024-39da2a204b63', 'is_active': True, 'description': 'Drive from point a to point b', 'id': 'c8235340-8ed4-11e9-8c1d-9de473423f0e', 'job_type': Decimal('1'), 'title': 'Drive the truck', 'job_status': Decimal('1')}
# {'created_dt': Decimal('1560545958070'), 'load_id': '5554434', 'modified_dt': Decimal('1560545958070'), 'created_by': 'd65cb4f0-8eb7-11e9-b024-39da2a204b63', 'end_dt': Decimal('1560977864000'), 'special_instructions': 'noee', 'start_dt': Decimal('1560977864000'), 'user_id': 'd65cb4f0-8eb7-11e9-b024-39da2a204b63', 'is_active': True, 'description': 'Driving more', 'id': '465e8560-8ee7-11e9-8c1d-9de473423f0e', 'job_type': Decimal('1'), 'title': 'Driving', 'job_status': Decimal('1')}
# {'created_dt': Decimal('1560545326536'), 'load_id': '1123123', 'modified_dt': Decimal('1560545326536'), 'created_by': 'd65cb4f0-8eb7-11e9-b024-39da2a204b63', 'end_dt': Decimal('1560804409000'), 'special_instructions': 'None', 'start_dt': Decimal('1560804409000'), 'user_id': 'd65cb4f0-8eb7-11e9-b024-39da2a204b63', 'is_active': True, 'description': 'Get from point A to point B', 'id': 'cdf21480-8ee5-11e9-8c1d-9de473423f0e', 'job_type': Decimal('1'), 'title': 'Drive my truck', 'job_status': Decimal('1')}

# %%
table = dynamodb.Table('job_task')
resp = table.query(KeyConditionExpression =Key('job_id').eq('cdf21480-8ee5-11e9-8c1d-9de473423f0e'))
resp
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-92-348308641c5c> in <module>
#       1 from boto3.dynamodb.conditions import Key, Attr
#       2 table = dynamodb.Table('job_task')
# ----> 3 resp = table.query(KeyConditionExpression =Key('job_id').eq('cdf21480-8ee5-11e9-8c1d-9de473423f0e'))
#       4 resp
#
# ~/anaconda3/lib/python3.7/site-packages/boto3/resources/factory.py in do_action(self, *args, **kwargs)
#     518             # instance via ``self``.
#     519             def do_action(self, *args, **kwargs):
# --> 520                 response = action(self, *args, **kwargs)
#     521
#     522                 if hasattr(self, 'load'):
#
# ~/anaconda3/lib/python3.7/site-packages/boto3/resources/action.py in __call__(self, parent, *args, **kwargs)
#      81                     operation_name, params)
#      82
# ---> 83         response = getattr(parent.meta.client, operation_name)(**params)
#      84
#      85         logger.debug('Response: %r', response)
#
# ~/anaconda3/lib/python3.7/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/lib/python3.7/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     659             error_code = parsed_response.get("Error", {}).get("Code")
#     660             error_class = self.exceptions.from_code(error_code)
# --> 661             raise error_class(parsed_response, operation_name)
#     662         else:
#     663             return parsed_response
#
# ClientError: An error occurred (ValidationException) when calling the Query operation: Query condition missed key schema element: id

# %%
job_id = 'cdf21480-8ee5-11e9-8c1d-9de473423f0e'
fe = Key('job_id').eq(job_id)

resp = table.scan(FilterExpression = fe,)['Items']

# %%
table = dynamodb.Table('job')
resp = table.scan()
for elem in resp['Items']:
    try:
        print(elem.keys())
    except:
        print('ERRRORRRR')
# Out:
# dict_keys(['created_dt', 'load_id', 'modified_dt', 'created_by', 'end_dt', 'special_instructions', 'start_dt', 'user_id', 'is_active', 'description', 'id', 'job_type', 'title', 'job_status'])

# %%
def plot_job(map,table,job_id):
    """This method will make a query to the job_detail table and plot it on a folium map object with 
    directed arrows."""
    
    #query the job task table for the given job id
    fe = Key('job_id').eq(job_id)
    resp = table.scan(FilterExpression = fe)['Items'] 
    df = pd.DataFrame(resp).sort_values(by = 'dispatch_instruction')
    num_stops = int(df['dispatch_instruction'].max())
    # get location info (will be removed in future)
    df['lat']=df.apply(lambda x: lat_dict[(x['address']+ " " + x['city']+" " +x['state']).lower()],axis = 1)
    df['lon']=df.apply(lambda x: lon_dict[(x['address']+ " " +x['city']+" " +x['state']).lower()],axis = 1)
    #shift for plotting lines
    df['lat_st']=df['lat'].shift(1)
    df['lon_st']=df['lon'].shift(1)
    
    #if all locations have coordinates, plot the job.
    if len(df)> 0 & len(df[df['lon']==0])==0:
        colors = defaultdict(lambda: 'blue')
        colors[1]='green'
        colors[df['dispatch_instruction'].max()]='red'
        for row in df.iterrows():
            folium.Marker(location = [row[1]['lat'],row[1]['lon']],
                          icon=folium.Icon(color=colors[int(row[1]['dispatch_instruction'])])).add_to(map)
        for row in df.dropna(subset = ['lat_st']).iterrows():
            p1 = [row[1]['lat'],row[1]['lon']]
            p2 = [row[1]['lat_st'],row[1]['lon_st']]
            folium.PolyLine(locations=[p1, p2], color='blue',).add_to(map)
        
    return df

# %%
def plot_job_mc(map,mc,table,job_id):
    """This method will make a query to the job_detail table and plot it on a folium map object with 
    directed arrows."""
    
    #query the job task table for the given job id
    fe = Key('job_id').eq(job_id)
    resp = table.scan(FilterExpression = fe)['Items'] 
    df = pd.DataFrame(resp).sort_values(by = 'dispatch_instruction')
    num_stops = int(df['dispatch_instruction'].max())
    # get location info (will be removed in future)
    df['lat']=df.apply(lambda x: lat_dict[(x['address']+ " " + x['city']+" " +x['state']).lower()],axis = 1)
    df['lon']=df.apply(lambda x: lon_dict[(x['address']+ " " +x['city']+" " +x['state']).lower()],axis = 1)
    #shift for plotting lines
    df['lat_st']=df['lat'].shift(1)
    df['lon_st']=df['lon'].shift(1)
    
    #if all locations have coordinates, plot the job.
    if (len(df)> 0) & (len(df[df['lon']==0])==0):
        colors = defaultdict(lambda: 'blue')
        colors[1]='green'
        colors[df['dispatch_instruction'].max()]='red'
        for row in df.iterrows():
            mc.add_child(folium.Marker(location = [row[1]['lat'],row[1]['lon']],
                                       popup= make_popup(row[1]),
                          icon=folium.Icon(color=colors[int(row[1]['dispatch_instruction'])])))
        for row in df.dropna(subset = ['lat_st']).iterrows():
            p1 = [row[1]['lat'],row[1]['lon']]
            p2 = [row[1]['lat_st'],row[1]['lon_st']]
            folium.PolyLine(locations=[p1, p2], color='blue',).add_to(map)
        
    return df

# %%
def make_popup(row):
    return folium.Popup("Load ID: " + row['load_id']+ "<br>"+ row['title'] +"<br>"+row['address'] + " <br>" + \
                        row['city'] + " "+ row['state'],
                         max_width=150)

# %%
table = dynamodb.Table('job_task')
map = folium.Map(location=[40.7128, -74.0060],zoom_start=9)
mc = MarkerCluster()
df = pd.DataFrame()
all_jobs = pd.DataFrame()
jobs = set()
for elem in resp:
    jobs.add(elem['job_id'])
for job in jobs:
    temp_df = plot_job_mc(map,mc,table,job)
    all_jobs = all_jobs.append(temp_df)
    if (len(temp_df)> 0) & (len(temp_df[temp_df['lon']==0])==0):
        df = df.append(temp_df)
map.fit_bounds([[df['lat'].min(),df['lon'].min()],
                [df['lat'].max(),df['lon'].max()]])
map.add_child(mc)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
table = dynamodb.Table('job_task')
map = folium.Map(location=[40.7128, -74.0060],zoom_start=9)
df = plot_job(map,table,'f20029b0-8ee6-11e9-8c1d-9de473423f0e')
#map.fit_bounds([[df['lat'].min(),df['lon'].min()],
#                [df['lat'].max(),df['lon'].max()]])
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
table = dynamodb.Table('job_task')
job_id = 'cdf21480-8ee5-11e9-8c1d-9de473423f0e'
user_id='d65cb4f0-8eb7-11e9-b024-39da2a204b63'

fe = Key('created_by').eq(user_id)
#fe = Key('job_id').eq(job_id)
pe = "job_id"
resp = table.scan(ProjectionExpression = pe, FilterExpression = fe)['Items']
resp
# Out:
# [{'job_id': '465e8560-8ee7-11e9-8c1d-9de473423f0e'},
#  {'job_id': 'c8235340-8ed4-11e9-8c1d-9de473423f0e'},
#  {'job_id': 'f20029b0-8ee6-11e9-8c1d-9de473423f0e'},
#  {'job_id': 'c8235340-8ed4-11e9-8c1d-9de473423f0e'},
#  {'job_id': '465e8560-8ee7-11e9-8c1d-9de473423f0e'},
#  {'job_id': 'f20029b0-8ee6-11e9-8c1d-9de473423f0e'},
#  {'job_id': 'cdf21480-8ee5-11e9-8c1d-9de473423f0e'},
#  {'job_id': 'cdf21480-8ee5-11e9-8c1d-9de473423f0e'}]

# %%
table = dynamodb.Table('job_task')
map = folium.Map(location=[40.7128, -74.0060],zoom_start=9)
mc = MarkerCluster()
df = pd.DataFrame()
all_jobs = pd.DataFrame()
jobs = set()
for elem in resp:
    jobs.add(elem['job_id'])
for job in jobs:
    temp_df = plot_job(map,table,job)
    all_jobs = all_jobs.append(temp_df)
    if (len(temp_df)> 0) & (len(temp_df[temp_df['lon']==0])==0):
        df = df.append(temp_df)
map.fit_bounds([[df['lat'].min(),df['lon'].min()],
                [df['lat'].max(),df['lon'].max()]])
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
all_jobs
# Out:
#            address      city                            created_by  \
# 0    222 E 39th St  New York  d65cb4f0-8eb7-11e9-b024-39da2a204b63
# 1      41 Henry St  New York  d65cb4f0-8eb7-11e9-b024-39da2a204b63
# 2    222 E 39th St  New York  d65cb4f0-8eb7-11e9-b024-39da2a204b63
# 3  41 Henry Street  New York  d65cb4f0-8eb7-11e9-b024-39da2a204b63
# 4  9 Ten Broeck Pl    Albany  d65cb4f0-8eb7-11e9-b024-39da2a204b63
# 5      123 Main St  Columbus  d65cb4f0-8eb7-11e9-b024-39da2a204b63
# 6   123 E Broadway  New York  d65cb4f0-8eb7-11e9-b024-39da2a204b63
# 7  123 Main Street  Columbus  d65cb4f0-8eb7-11e9-b024-39da2a204b63
#
#       created_dt dispatch_instruction                                  id_x  \
# 0  1560538015388                    1  c82946b0-8ed4-11e9-8c1d-9de473423f0e
# 1  1560538015388                    2  c82946b1-8ed4-11e9-8c1d-9de473423f0e
# 2  1560545816563                    1  f2064430-8ee6-11e9-8c1d-9de473423f0e
# 3  1560545816563                    2  f2064431-8ee6-11e9-8c1d-9de473423f0e
# 4  1560545958106                    1  466403a0-8ee7-11e9-8c1d-9de473423f0e
# 5  1560545958106                    2  466403a1-8ee7-11e9-8c1d-9de473423f0e
# 6  1560545326573                    1  cdf7b9d0-8ee5-11e9-8c1d-9de473423f0e
# 7  1560545326573                    2  cdf7b9d1-8ee5-11e9-8c1d-9de473423f0e
#
#    is_completed                                job_id    modified_dt state  \
# 0         False  c8235340-8ed4-11e9-8c1d-9de473423f0e  1560538015388    NY
# 1         False  c8235340-8ed4-11e9-8c1d-9de473423f0e  1560538015388    NY
# 2         False  f20029b0-8ee6-11e9-8c1d-9de473423f0e  1560545816563    NY
# 3         False  f20029b0-8ee6-11e9-8c1d-9de473423f0e  1560545816563    NY
# 4         False  465e8560-8ee7-11e9-8c1d-9de473423f0e  1560545958106    NY
# 5         False  465e8560-8ee7-11e9-8c1d-9de473423f0e  1560545958106    OH
# 6         False  cdf21480-8ee5-11e9-8c1d-9de473423f0e  1560545326573    NY
# 7         False  cdf21480-8ee5-11e9-8c1d-9de473423f0e  1560545326573    OH
#
#          lat        lon     lat_st     lon_st  \
# 0   0.000000   0.000000        NaN        NaN
# 1   0.000000   0.000000   0.000000   0.000000
# 2   0.000000   0.000000        NaN        NaN
# 3   0.000000   0.000000   0.000000   0.000000
# 4  42.658293 -73.751163        NaN        NaN
# 5  39.955681 -83.002757  42.658293 -73.751163
# 6  40.734749 -73.990611        NaN        NaN
# 7  39.955681 -83.002757  40.734749 -73.990611
#
#                                    id_y     load_id            title
# 0  c8235340-8ed4-11e9-8c1d-9de473423f0e   Test load  Drive the truck
# 1  c8235340-8ed4-11e9-8c1d-9de473423f0e   Test load  Drive the truck
# 2  f20029b0-8ee6-11e9-8c1d-9de473423f0e  1231231231          Driving
# 3  f20029b0-8ee6-11e9-8c1d-9de473423f0e  1231231231          Driving
# 4  465e8560-8ee7-11e9-8c1d-9de473423f0e     5554434          Driving
# 5  465e8560-8ee7-11e9-8c1d-9de473423f0e     5554434          Driving
# 6  cdf21480-8ee5-11e9-8c1d-9de473423f0e     1123123   Drive my truck
# 7  cdf21480-8ee5-11e9-8c1d-9de473423f0e     1123123   Drive my truck

# %%
(len(temp_df)> 0) & (len(temp_df[temp_df['lon']==0])==0)
# Out:
# False

# %%
lat_dict = defaultdict(int)
lon_dict = defaultdict(int)
address = "9 Ten Broeck Pl albany NY".lower()
lat_dict[address] = 42.658293
lon_dict[address] = -73.751163

address = "123 main street columbus OH".lower()
lat_dict[address] = 39.955681
lon_dict[address] = -83.002757

address = "123 main st columbus OH".lower()
lat_dict[address] = 39.955681
lon_dict[address] = -83.002757

address = "123 e broadway new york ny".lower()
lat_dict[address] = 40.734749
lon_dict[address] = -73.990611

address = "123 main street philadelphia PA".lower()
lat_dict[address] = 40.022975
lon_dict[address] = -75.219292

address = "355 grand st jersey city NJ".lower()
lat_dict[address] = 40.715257
lon_dict[address] = -74.050824

address = "206 Springfield ave newark NJ".lower()
lat_dict[address] = 40.736681
lon_dict[address] = -74.186132

address = "600 N charles st baltimore MD".lower()
lat_dict[address] = 39.296570
lon_dict[address] = -76.616106

# %%
grp = all_jobs.groupby(by = 'created_dt')
l1 = []
grp.agg(test_agg)
l1
# Out:
# ['c8235340-8ed4-11e9-8c1d-9de473423f0e',
#  'cdf21480-8ee5-11e9-8c1d-9de473423f0e',
#  'f20029b0-8ee6-11e9-8c1d-9de473423f0e',
#  '465e8560-8ee7-11e9-8c1d-9de473423f0e']

# %%
def test_agg(df):
    l1.append(df['job_id'].unique()[0])

# %%
def get_job_df(map,mc,table,job_id):
    """This method will make a query to the job_detail table and plot it on a folium map object with 
    directed arrows."""
    
    #query the job task table for the given job id
    fe = Key('job_id').eq(job_id)
    resp = table.scan(FilterExpression = fe)['Items'] 
    df = pd.DataFrame(resp).sort_values(by = 'id').reset_index()
    num_stops = len(df)
    df['stop']= df.index+1
    # get location info (will be removed in future)
    df['lat']=df.apply(lambda x: lat_dict[(x['address']+ " " + x['city']+" " +x['state']).lower()],axis = 1)
    df['lon']=df.apply(lambda x: lon_dict[(x['address']+ " " +x['city']+" " +x['state']).lower()],axis = 1)
    #shift for plotting lines
    df['lat_st']=df['lat'].shift(1)
    df['lon_st']=df['lon'].shift(1)
    return df

# %%
def get_job_df_test(map,mc,table,job_id):
    """This method will make a query to the job_detail table and plot it on a folium map object with 
    directed arrows."""
    
    #query the job task table for the given job id
    fe = Key('job_id').eq(job_id)
    resp = table.scan(FilterExpression = fe)['Items'] 
    df = pd.DataFrame(resp)
    num_stops = len(df)
    # get location info (will be removed in future)
    df['lat']=df.apply(lambda x: lat_dict[(x['address']+ " " + x['city']+" " +x['state']).lower()],axis = 1)
    df['lon']=df.apply(lambda x: lon_dict[(x['address']+ " " +x['city']+" " +x['state']).lower()],axis = 1)
    #shift for plotting lines
    df['lat_st']=df['lat'].shift(1)
    df['lon_st']=df['lon'].shift(1)
    return df

# %%
def plot_job_df_test(map,mc,df):
    """This method will take a dataframe containing all tasks for a job, and then plot it on a map object if 
    it is a valid job. """
    
    #if all locations have coordinates, plot the job.
    if (len(df)> 0) & (len(df[df['lon']==0])==0):
        colors = defaultdict(lambda: 'blue')
        colors[1]='green'
        colors[df['stop'].max()]='red'
        for row in df.iterrows():
            mc.add_child(folium.Marker(location = [row[1]['lat'],row[1]['lon']],
                          icon=folium.Icon(color=colors[int(row[1]['stop'])])))
        for row in df.dropna(subset = ['lat_st']).iterrows():
            p1 = [row[1]['lat'],row[1]['lon']]
            p2 = [row[1]['lat_st'],row[1]['lon_st']]
            folium.PolyLine(locations=[p1, p2], color='blue',).add_to(map)
    return None

# %%
table = dynamodb.Table('job_task')
map = folium.Map(location=[40.7128, -74.0060],zoom_start=9)
mc = MarkerCluster()
df = pd.DataFrame()
all_jobs = pd.DataFrame()
jobs = set()

user_id='d65cb4f0-8eb7-11e9-b024-39da2a204b63'

fe = Key('created_by').eq(user_id)
pe = "job_id"
resp = table.scan(ProjectionExpression = pe, FilterExpression = fe)['Items']

for elem in resp:
    jobs.add(elem['job_id'])
for job in jobs:
    all_jobs = all_jobs.append(get_job_df_test(map,mc,table,job))

df = all_jobs[all_jobs['lat']!= 0]
grp = all_jobs.groupby(by = 'job_id')

grp.agg(lambda x: plot_job_df_test(map,mc,x))
map.fit_bounds([[df['lat'].min(),df['lon'].min()],
                [df['lat'].max(),df['lon'].max()]])
map.add_child(mc)
map
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func)
#     589         try:
# --> 590             return self._aggregate_series_fast(obj, func)
#     591         except Exception:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in _aggregate_series_fast(self, obj, func)
#     609                                           dummy)
# --> 610         result, counts = grouper.get_result()
#     611         return result, counts
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#     843         func = self._is_builtin_func(func)
# --> 844         f = lambda x: func(x, *args, **kwargs)
#     845
#
# <ipython-input-17-da290fee2017> in <lambda>(x)
#      21
# ---> 22 grp.agg(lambda x: plot_job_df_test(map,mc,x))
#      23 map.fit_bounds([[df['lat'].min(),df['lon'].min()],
#
# <ipython-input-16-4514c54e4cc4> in plot_job_df_test(map, mc, df)
#       5     #if all locations have coordinates, plot the job.
# ----> 6     if (len(df)> 0) & (len(df[df['lon']==0])==0):
#       7         colors = defaultdict(lambda: 'blue')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'lon'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     775             try:
# --> 776                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     777             except Exception:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     849             try:
# --> 850                 result, counts = self.grouper.agg_series(obj, f)
#     851                 output[name] = self._try_cast(result, obj, numeric_only=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func)
#     591         except Exception:
# --> 592             return self._aggregate_series_pure_python(obj, func)
#     593
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     622         for label, group in splitter:
# --> 623             res = func(group)
#     624             if result is None:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#     843         func = self._is_builtin_func(func)
# --> 844         f = lambda x: func(x, *args, **kwargs)
#     845
#
# <ipython-input-17-da290fee2017> in <lambda>(x)
#      21
# ---> 22 grp.agg(lambda x: plot_job_df_test(map,mc,x))
#      23 map.fit_bounds([[df['lat'].min(),df['lon'].min()],
#
# <ipython-input-16-4514c54e4cc4> in plot_job_df_test(map, mc, df)
#       5     #if all locations have coordinates, plot the job.
# ----> 6     if (len(df)> 0) & (len(df[df['lon']==0])==0):
#       7         colors = defaultdict(lambda: 'blue')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'lon'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, arg, *args, **kwargs)
#     200                     result = self._aggregate_multiple_funcs(
# --> 201                         [arg], _level=_level, _axis=self.axis)
#     202                     result.columns = Index(
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/base.py in _aggregate_multiple_funcs(self, arg, _level, _axis)
#     604                                          subset=obj.iloc[:, index])
# --> 605                     results.append(colg.aggregate(arg))
#     606                     keys.append(col)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     765             ret = self._aggregate_multiple_funcs(func_or_funcs,
# --> 766                                                  (_level or 0) + 1)
#     767         else:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _aggregate_multiple_funcs(self, arg, _level)
#     839                 obj._selection = name
# --> 840             results[name] = obj.aggregate(func)
#     841
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     777             except Exception:
# --> 778                 result = self._aggregate_named(func_or_funcs, *args, **kwargs)
#     779
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _aggregate_named(self, func, *args, **kwargs)
#     906             group.name = name
# --> 907             output = func(group, *args, **kwargs)
#     908             if isinstance(output, (Series, Index, np.ndarray)):
#
# <ipython-input-17-da290fee2017> in <lambda>(x)
#      21
# ---> 22 grp.agg(lambda x: plot_job_df_test(map,mc,x))
#      23 map.fit_bounds([[df['lat'].min(),df['lon'].min()],
#
# <ipython-input-16-4514c54e4cc4> in plot_job_df_test(map, mc, df)
#       5     #if all locations have coordinates, plot the job.
# ----> 6     if (len(df)> 0) & (len(df[df['lon']==0])==0):
#       7         colors = defaultdict(lambda: 'blue')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'lon'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'stop'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _aggregate_generic(self, func, *args, **kwargs)
#     226                 for name, data in self:
# --> 227                     result[name] = self._try_cast(func(data, *args, **kwargs),
#     228                                                   data)
#
# <ipython-input-17-da290fee2017> in <lambda>(x)
#      21
# ---> 22 grp.agg(lambda x: plot_job_df_test(map,mc,x))
#      23 map.fit_bounds([[df['lat'].min(),df['lon'].min()],
#
# <ipython-input-16-4514c54e4cc4> in plot_job_df_test(map, mc, df)
#       8         colors[1]='green'
# ----> 9         colors[df['stop'].max()]='red'
#      10         for row in df.iterrows():
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'stop'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func)
#     589         try:
# --> 590             return self._aggregate_series_fast(obj, func)
#     591         except Exception:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in _aggregate_series_fast(self, obj, func)
#     609                                           dummy)
# --> 610         result, counts = grouper.get_result()
#     611         return result, counts
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#     843         func = self._is_builtin_func(func)
# --> 844         f = lambda x: func(x, *args, **kwargs)
#     845
#
# <ipython-input-17-da290fee2017> in <lambda>(x)
#      21
# ---> 22 grp.agg(lambda x: plot_job_df_test(map,mc,x))
#      23 map.fit_bounds([[df['lat'].min(),df['lon'].min()],
#
# <ipython-input-16-4514c54e4cc4> in plot_job_df_test(map, mc, df)
#       5     #if all locations have coordinates, plot the job.
# ----> 6     if (len(df)> 0) & (len(df[df['lon']==0])==0):
#       7         colors = defaultdict(lambda: 'blue')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'lon'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     775             try:
# --> 776                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     777             except Exception:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     849             try:
# --> 850                 result, counts = self.grouper.agg_series(obj, f)
#     851                 output[name] = self._try_cast(result, obj, numeric_only=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func)
#     591         except Exception:
# --> 592             return self._aggregate_series_pure_python(obj, func)
#     593
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     622         for label, group in splitter:
# --> 623             res = func(group)
#     624             if result is None:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#     843         func = self._is_builtin_func(func)
# --> 844         f = lambda x: func(x, *args, **kwargs)
#     845
#
# <ipython-input-17-da290fee2017> in <lambda>(x)
#      21
# ---> 22 grp.agg(lambda x: plot_job_df_test(map,mc,x))
#      23 map.fit_bounds([[df['lat'].min(),df['lon'].min()],
#
# <ipython-input-16-4514c54e4cc4> in plot_job_df_test(map, mc, df)
#       5     #if all locations have coordinates, plot the job.
# ----> 6     if (len(df)> 0) & (len(df[df['lon']==0])==0):
#       7         colors = defaultdict(lambda: 'blue')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'lon'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-da290fee2017> in <module>
#      20 grp = all_jobs.groupby(by = 'job_id')
#      21
# ---> 22 grp.agg(lambda x: plot_job_df_test(map,mc,x))
#      23 map.fit_bounds([[df['lat'].min(),df['lon'].min()],
#      24                 [df['lat'].max(),df['lon'].max()]])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, arg, *args, **kwargs)
#    1313     @Appender(_shared_docs['aggregate'])
#    1314     def aggregate(self, arg, *args, **kwargs):
# -> 1315         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    1316
#    1317     agg = aggregate
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, arg, *args, **kwargs)
#     204                         name=self._selected_obj.columns.name)
#     205                 except Exception:
# --> 206                     result = self._aggregate_generic(arg, *args, **kwargs)
#     207
#     208         if not self.as_index:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _aggregate_generic(self, func, *args, **kwargs)
#     228                                                   data)
#     229             except Exception:
# --> 230                 return self._aggregate_item_by_item(func, *args, **kwargs)
#     231         else:
#     232             for name in self.indices:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _aggregate_item_by_item(self, func, *args, **kwargs)
#     257                                      grouper=self.grouper)
#     258                 result[item] = self._try_cast(
# --> 259                     colg.aggregate(func, *args, **kwargs), data)
#     260             except ValueError:
#     261                 cannot_agg.append(item)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     776                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     777             except Exception:
# --> 778                 result = self._aggregate_named(func_or_funcs, *args, **kwargs)
#     779
#     780             index = Index(sorted(result), name=self.grouper.names[0])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _aggregate_named(self, func, *args, **kwargs)
#     905         for name, group in self:
#     906             group.name = name
# --> 907             output = func(group, *args, **kwargs)
#     908             if isinstance(output, (Series, Index, np.ndarray)):
#     909                 raise Exception('Must produce aggregated value')
#
# <ipython-input-17-da290fee2017> in <lambda>(x)
#      20 grp = all_jobs.groupby(by = 'job_id')
#      21
# ---> 22 grp.agg(lambda x: plot_job_df_test(map,mc,x))
#      23 map.fit_bounds([[df['lat'].min(),df['lon'].min()],
#      24                 [df['lat'].max(),df['lon'].max()]])
#
# <ipython-input-16-4514c54e4cc4> in plot_job_df_test(map, mc, df)
#       4
#       5     #if all locations have coordinates, plot the job.
# ----> 6     if (len(df)> 0) & (len(df[df['lon']==0])==0):
#       7         colors = defaultdict(lambda: 'blue')
#       8         colors[1]='green'
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'lon'

# %%
grp.
# Out:
#                address          city                            created_by  \
# 0     600 N Charles St     Baltimore  d65cb4f0-8eb7-11e9-b024-39da2a204b63
# 1      123 Main street  Philadelphia  d65cb4f0-8eb7-11e9-b024-39da2a204b63
# 2  206 Springfield Ave        Newark  d65cb4f0-8eb7-11e9-b024-39da2a204b63
# 0      9 Ten Broeck Pl        Albany  d65cb4f0-8eb7-11e9-b024-39da2a204b63
# 1          123 Main St      Columbus  d65cb4f0-8eb7-11e9-b024-39da2a204b63
# 0     600 N Charles St     Baltimore  d65cb4f0-8eb7-11e9-b024-39da2a204b63
# 1          123 Main St      Columbus  d65cb4f0-8eb7-11e9-b024-39da2a204b63
# 2         355 Grand St   Jersey City  d65cb4f0-8eb7-11e9-b024-39da2a204b63
# 0      123 Main Street      Columbus  d65cb4f0-8eb7-11e9-b024-39da2a204b63
# 1       123 E Broadway      New York  d65cb4f0-8eb7-11e9-b024-39da2a204b63
#
#       created_dt dispatch_instruction                                    id  \
# 0  1560800144627                    2  195d1432-9137-11e9-8c1d-9de473423f0e
# 1  1560800144627                    2  195d1431-9137-11e9-8c1d-9de473423f0e
# 2  1560800144627                    1  195d1430-9137-11e9-8c1d-9de473423f0e
# 0  1560545958106                    1  466403a0-8ee7-11e9-8c1d-9de473423f0e
# 1  1560545958106                    2  466403a1-8ee7-11e9-8c1d-9de473423f0e
# 0  1560800763486                    2  8a3b77e2-9138-11e9-8c1d-9de473423f0e
# 1  1560800763486                    2  8a3b77e1-9138-11e9-8c1d-9de473423f0e
# 2  1560800763486                    1  8a3b77e0-9138-11e9-8c1d-9de473423f0e
# 0  1560545326573                    2  cdf7b9d1-8ee5-11e9-8c1d-9de473423f0e
# 1  1560545326573                    1  cdf7b9d0-8ee5-11e9-8c1d-9de473423f0e
#
#    is_completed                                job_id    modified_dt state  \
# 0         False  195795f0-9137-11e9-8c1d-9de473423f0e  1560800144627    MD
# 1         False  195795f0-9137-11e9-8c1d-9de473423f0e  1560800144627    PA
# 2         False  195795f0-9137-11e9-8c1d-9de473423f0e  1560800144627    NJ
# 0         False  465e8560-8ee7-11e9-8c1d-9de473423f0e  1560545958106    NY
# 1         False  465e8560-8ee7-11e9-8c1d-9de473423f0e  1560545958106    OH
# 0         False  8a35f9a0-9138-11e9-8c1d-9de473423f0e  1560800763486    MD
# 1         False  8a35f9a0-9138-11e9-8c1d-9de473423f0e  1560800763486    OH
# 2         False  8a35f9a0-9138-11e9-8c1d-9de473423f0e  1560800763486    NJ
# 0         False  cdf21480-8ee5-11e9-8c1d-9de473423f0e  1560545326573    OH
# 1         False  cdf21480-8ee5-11e9-8c1d-9de473423f0e  1560545326573    NY
#
#          lat        lon     lat_st     lon_st
# 0  39.296570 -76.616106        NaN        NaN
# 1  40.022975 -75.219292  39.296570 -76.616106
# 2  40.736681 -74.186132  40.022975 -75.219292
# 0  42.658293 -73.751163        NaN        NaN
# 1  39.955681 -83.002757  42.658293 -73.751163
# 0  39.296570 -76.616106        NaN        NaN
# 1  39.955681 -83.002757  39.296570 -76.616106
# 2  40.715257 -74.050824  39.955681 -83.002757
# 0  39.955681 -83.002757        NaN        NaN
# 1  40.734749 -73.990611  39.955681 -83.002757

# %%
def plot_job_df(map,mc,df):
    """This method will take a dataframe containing all tasks for a job, and then plot it on a map object if 
    it is a valid job. """
    
    #if all locations have coordinates, plot the job.
    if (len(df)> 0) & (len(df[df['lon']==0])==0):
        colors = defaultdict(lambda: 'blue')
        colors[1]='green'
        colors[df['stop'].max()]='red'
        for row in df.iterrows():
            mc.add_child(folium.Marker(location = [row[1]['lat'],row[1]['lon']],
                                       popup= make_popup(row[1]),
                          icon=folium.Icon(color=colors[int(row[1]['stop'])])))
        for row in df.dropna(subset = ['lat_st']).iterrows():
            p1 = [row[1]['lat'],row[1]['lon']]
            p2 = [row[1]['lat_st'],row[1]['lon_st']]
            folium.PolyLine(locations=[p1, p2], color='blue',).add_to(map)
            arrows = get_arrows(locations=[p1, p2], color='#FFFFFF', n_arrows=3)
            for arrow in arrows:
                arrow.add_to(map)
            
        
    return None

# %%
def get_bearing(p1, p2):
    
    '''
    Returns compass bearing from p1 to p2
    
    Parameters
    p1 : namedtuple with lat lon
    p2 : namedtuple with lat lon
    
    Return
    compass bearing of type float
    
    Notes
    Based on https://gist.github.com/jeromer/2005586
    '''
    
    long_diff = np.radians(p2.lon - p1.lon)
    
    lat1 = np.radians(p1.lat)
    lat2 = np.radians(p2.lat)
    
    x = np.sin(long_diff) * np.cos(lat2)
    y = (np.cos(lat1) * np.sin(lat2) 
        - (np.sin(lat1) * np.cos(lat2) 
        * np.cos(long_diff)))

    bearing = np.degrees(np.arctan2(x, y))
    
    # adjusting for compass bearing
    if bearing < 0:
        return bearing + 360
    return bearing


def get_arrows(locations, color='blue', size=6, n_arrows=3):
    
    '''
    Get a list of correctly placed and rotated 
    arrows/markers to be plotted
    
    Parameters
    locations : list of lists of lat lons that represent the 
                start and end of the line. 
                eg [[41.1132, -96.1993],[41.3810, -95.8021]]
    arrow_color : whatever folium can use.  default is 'blue'
    size : default is 6
    n_arrows : number of arrows to create.  default is 3

    Return
    list of arrows/markers
    '''
    
    Point = namedtuple('Point', field_names=['lat', 'lon'])
    
    # creating point from our Point named tuple
    p1 = Point(locations[0][0], locations[0][1])
    p2 = Point(locations[1][0], locations[1][1])
    
    # getting the rotation needed for our marker.  
    # Subtracting 90 to account for the marker's orientation
    # of due East(get_bearing returns North)
    rotation = get_bearing(p1, p2) - 90
    
    # get an evenly space list of lats and lons for our arrows
    # note that I'm discarding the first and last for aesthetics
    # as I'm using markers to denote the start and end
    arrow_lats = np.linspace(p1.lat, p2.lat, n_arrows + 2)[1:n_arrows+1]
    arrow_lons = np.linspace(p1.lon, p2.lon, n_arrows + 2)[1:n_arrows+1]
    
    arrows = []
    
    #creating each "arrow" and appending them to our arrows list
    for points in zip(arrow_lats, arrow_lons):
        arrows.append(folium.RegularPolygonMarker(location=points, 
                      fill_color=color, number_of_sides=3, 
                      radius=size, rotation=rotation))
    return arrows

# %%
table = dynamodb.Table('job_task')
map = folium.Map(location=[40.7128, -74.0060],zoom_start=9)
mc = MarkerCluster()
df = pd.DataFrame()
all_jobs = pd.DataFrame()
jobs = set()

user_id='d65cb4f0-8eb7-11e9-b024-39da2a204b63'

fe = Key('created_by').eq(user_id)
pe = "job_id"
resp = table.scan(ProjectionExpression = pe, FilterExpression = fe)['Items']

for elem in resp:
    jobs.add(elem['job_id'])
for job in jobs:
    all_jobs = all_jobs.append(get_job_df(map,mc,table,job))

table = dynamodb.Table('job')

fe = Key('user_id').eq(user_id)
resp = table.scan( FilterExpression = fe)['Items']
job_cols = ['id','load_id','title']
all_jobs = all_jobs.merge(pd.DataFrame(resp)[job_cols],how = 'left',left_on='job_id',right_on = 'id')

df = all_jobs[all_jobs['lat']!= 0]
grp = all_jobs.groupby(by = 'job_id')

grp.agg(lambda x: plot_job_df(map,mc,x))
map.fit_bounds([[df['lat'].min(),df['lon'].min()],
                [df['lat'].max(),df['lon'].max()]])
map.add_child(mc)
map
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func)
#     589         try:
# --> 590             return self._aggregate_series_fast(obj, func)
#     591         except Exception:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in _aggregate_series_fast(self, obj, func)
#     609                                           dummy)
# --> 610         result, counts = grouper.get_result()
#     611         return result, counts
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#     843         func = self._is_builtin_func(func)
# --> 844         f = lambda x: func(x, *args, **kwargs)
#     845
#
# <ipython-input-397-dd981be4e171> in <lambda>(x)
#      28
# ---> 29 grp.agg(lambda x: plot_job_df(map,mc,x))
#      30 map.fit_bounds([[df['lat'].min(),df['lon'].min()],
#
# <ipython-input-396-ec3724748630> in plot_job_df(map, mc, df)
#       5     #if all locations have coordinates, plot the job.
# ----> 6     if (len(df)> 0) & (len(df[df['lon']==0])==0):
#       7         colors = defaultdict(lambda: 'blue')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'lon'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     775             try:
# --> 776                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     777             except Exception:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     849             try:
# --> 850                 result, counts = self.grouper.agg_series(obj, f)
#     851                 output[name] = self._try_cast(result, obj, numeric_only=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func)
#     591         except Exception:
# --> 592             return self._aggregate_series_pure_python(obj, func)
#     593
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     622         for label, group in splitter:
# --> 623             res = func(group)
#     624             if result is None:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#     843         func = self._is_builtin_func(func)
# --> 844         f = lambda x: func(x, *args, **kwargs)
#     845
#
# <ipython-input-397-dd981be4e171> in <lambda>(x)
#      28
# ---> 29 grp.agg(lambda x: plot_job_df(map,mc,x))
#      30 map.fit_bounds([[df['lat'].min(),df['lon'].min()],
#
# <ipython-input-396-ec3724748630> in plot_job_df(map, mc, df)
#       5     #if all locations have coordinates, plot the job.
# ----> 6     if (len(df)> 0) & (len(df[df['lon']==0])==0):
#       7         colors = defaultdict(lambda: 'blue')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'lon'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, arg, *args, **kwargs)
#     200                     result = self._aggregate_multiple_funcs(
# --> 201                         [arg], _level=_level, _axis=self.axis)
#     202                     result.columns = Index(
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/base.py in _aggregate_multiple_funcs(self, arg, _level, _axis)
#     604                                          subset=obj.iloc[:, index])
# --> 605                     results.append(colg.aggregate(arg))
#     606                     keys.append(col)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     765             ret = self._aggregate_multiple_funcs(func_or_funcs,
# --> 766                                                  (_level or 0) + 1)
#     767         else:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _aggregate_multiple_funcs(self, arg, _level)
#     839                 obj._selection = name
# --> 840             results[name] = obj.aggregate(func)
#     841
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     777             except Exception:
# --> 778                 result = self._aggregate_named(func_or_funcs, *args, **kwargs)
#     779
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _aggregate_named(self, func, *args, **kwargs)
#     906             group.name = name
# --> 907             output = func(group, *args, **kwargs)
#     908             if isinstance(output, (Series, Index, np.ndarray)):
#
# <ipython-input-397-dd981be4e171> in <lambda>(x)
#      28
# ---> 29 grp.agg(lambda x: plot_job_df(map,mc,x))
#      30 map.fit_bounds([[df['lat'].min(),df['lon'].min()],
#
# <ipython-input-396-ec3724748630> in plot_job_df(map, mc, df)
#       5     #if all locations have coordinates, plot the job.
# ----> 6     if (len(df)> 0) & (len(df[df['lon']==0])==0):
#       7         colors = defaultdict(lambda: 'blue')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'lon'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _aggregate_generic(self, func, *args, **kwargs)
#     226                 for name, data in self:
# --> 227                     result[name] = self._try_cast(func(data, *args, **kwargs),
#     228                                                   data)
#
# <ipython-input-397-dd981be4e171> in <lambda>(x)
#      28
# ---> 29 grp.agg(lambda x: plot_job_df(map,mc,x))
#      30 map.fit_bounds([[df['lat'].min(),df['lon'].min()],
#
# <ipython-input-396-ec3724748630> in plot_job_df(map, mc, df)
#      17             folium.PolyLine(locations=[p1, p2], color='blue',).add_to(map)
# ---> 18             arrows = get_arrows(locations=[p1, p2], color='#FFFFFF', n_arrows=3)
#      19             for arrow in arrows:
#
# <ipython-input-367-208002f54122> in get_arrows(locations, color, size, n_arrows)
#      52
# ---> 53     Point = namedtuple('Point', field_names=['lat', 'lon'])
#      54
#
# NameError: name 'namedtuple' is not defined
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func)
#     589         try:
# --> 590             return self._aggregate_series_fast(obj, func)
#     591         except Exception:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in _aggregate_series_fast(self, obj, func)
#     609                                           dummy)
# --> 610         result, counts = grouper.get_result()
#     611         return result, counts
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#     843         func = self._is_builtin_func(func)
# --> 844         f = lambda x: func(x, *args, **kwargs)
#     845
#
# <ipython-input-397-dd981be4e171> in <lambda>(x)
#      28
# ---> 29 grp.agg(lambda x: plot_job_df(map,mc,x))
#      30 map.fit_bounds([[df['lat'].min(),df['lon'].min()],
#
# <ipython-input-396-ec3724748630> in plot_job_df(map, mc, df)
#       5     #if all locations have coordinates, plot the job.
# ----> 6     if (len(df)> 0) & (len(df[df['lon']==0])==0):
#       7         colors = defaultdict(lambda: 'blue')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'lon'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     775             try:
# --> 776                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     777             except Exception:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     849             try:
# --> 850                 result, counts = self.grouper.agg_series(obj, f)
#     851                 output[name] = self._try_cast(result, obj, numeric_only=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func)
#     591         except Exception:
# --> 592             return self._aggregate_series_pure_python(obj, func)
#     593
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     622         for label, group in splitter:
# --> 623             res = func(group)
#     624             if result is None:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#     843         func = self._is_builtin_func(func)
# --> 844         f = lambda x: func(x, *args, **kwargs)
#     845
#
# <ipython-input-397-dd981be4e171> in <lambda>(x)
#      28
# ---> 29 grp.agg(lambda x: plot_job_df(map,mc,x))
#      30 map.fit_bounds([[df['lat'].min(),df['lon'].min()],
#
# <ipython-input-396-ec3724748630> in plot_job_df(map, mc, df)
#       5     #if all locations have coordinates, plot the job.
# ----> 6     if (len(df)> 0) & (len(df[df['lon']==0])==0):
#       7         colors = defaultdict(lambda: 'blue')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'lon'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-397-dd981be4e171> in <module>
#      27 grp = all_jobs.groupby(by = 'job_id')
#      28
# ---> 29 grp.agg(lambda x: plot_job_df(map,mc,x))
#      30 map.fit_bounds([[df['lat'].min(),df['lon'].min()],
#      31                 [df['lat'].max(),df['lon'].max()]])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, arg, *args, **kwargs)
#    1313     @Appender(_shared_docs['aggregate'])
#    1314     def aggregate(self, arg, *args, **kwargs):
# -> 1315         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    1316
#    1317     agg = aggregate
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, arg, *args, **kwargs)
#     204                         name=self._selected_obj.columns.name)
#     205                 except Exception:
# --> 206                     result = self._aggregate_generic(arg, *args, **kwargs)
#     207
#     208         if not self.as_index:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _aggregate_generic(self, func, *args, **kwargs)
#     228                                                   data)
#     229             except Exception:
# --> 230                 return self._aggregate_item_by_item(func, *args, **kwargs)
#     231         else:
#     232             for name in self.indices:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _aggregate_item_by_item(self, func, *args, **kwargs)
#     257                                      grouper=self.grouper)
#     258                 result[item] = self._try_cast(
# --> 259                     colg.aggregate(func, *args, **kwargs), data)
#     260             except ValueError:
#     261                 cannot_agg.append(item)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     776                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     777             except Exception:
# --> 778                 result = self._aggregate_named(func_or_funcs, *args, **kwargs)
#     779
#     780             index = Index(sorted(result), name=self.grouper.names[0])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _aggregate_named(self, func, *args, **kwargs)
#     905         for name, group in self:
#     906             group.name = name
# --> 907             output = func(group, *args, **kwargs)
#     908             if isinstance(output, (Series, Index, np.ndarray)):
#     909                 raise Exception('Must produce aggregated value')
#
# <ipython-input-397-dd981be4e171> in <lambda>(x)
#      27 grp = all_jobs.groupby(by = 'job_id')
#      28
# ---> 29 grp.agg(lambda x: plot_job_df(map,mc,x))
#      30 map.fit_bounds([[df['lat'].min(),df['lon'].min()],
#      31                 [df['lat'].max(),df['lon'].max()]])
#
# <ipython-input-396-ec3724748630> in plot_job_df(map, mc, df)
#       4
#       5     #if all locations have coordinates, plot the job.
# ----> 6     if (len(df)> 0) & (len(df[df['lon']==0])==0):
#       7         colors = defaultdict(lambda: 'blue')
#       8         colors[1]='green'
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'lon'

# %%
def test_lambda(df):
    return df.index

# %%
grp.agg(lambda x: test_lambda(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func)
#     589         try:
# --> 590             return self._aggregate_series_fast(obj, func)
#     591         except Exception:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in _aggregate_series_fast(self, obj, func)
#     609                                           dummy)
# --> 610         result, counts = grouper.get_result()
#     611         return result, counts
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction._get_result_array()
#
# ValueError: function does not reduce
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     775             try:
# --> 776                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     777             except Exception:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     849             try:
# --> 850                 result, counts = self.grouper.agg_series(obj, f)
#     851                 output[name] = self._try_cast(result, obj, numeric_only=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func)
#     591         except Exception:
# --> 592             return self._aggregate_series_pure_python(obj, func)
#     593
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     625                 if (isinstance(res, (Series, Index, np.ndarray))):
# --> 626                     raise ValueError('Function does not reduce')
#     627                 result = np.empty(ngroups, dtype='O')
#
# ValueError: Function does not reduce
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, arg, *args, **kwargs)
#     200                     result = self._aggregate_multiple_funcs(
# --> 201                         [arg], _level=_level, _axis=self.axis)
#     202                     result.columns = Index(
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/base.py in _aggregate_multiple_funcs(self, arg, _level, _axis)
#     604                                          subset=obj.iloc[:, index])
# --> 605                     results.append(colg.aggregate(arg))
#     606                     keys.append(col)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     765             ret = self._aggregate_multiple_funcs(func_or_funcs,
# --> 766                                                  (_level or 0) + 1)
#     767         else:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _aggregate_multiple_funcs(self, arg, _level)
#     839                 obj._selection = name
# --> 840             results[name] = obj.aggregate(func)
#     841
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     777             except Exception:
# --> 778                 result = self._aggregate_named(func_or_funcs, *args, **kwargs)
#     779
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _aggregate_named(self, func, *args, **kwargs)
#     908             if isinstance(output, (Series, Index, np.ndarray)):
# --> 909                 raise Exception('Must produce aggregated value')
#     910             result[name] = self._try_cast(output, group)
#
# Exception: Must produce aggregated value
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1665     try:
# -> 1666         blocks = form_blocks(arrays, names, axes)
#    1667         mgr = BlockManager(blocks, axes)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in form_blocks(arrays, names, axes)
#    1733     if len(items_dict['IntBlock']):
# -> 1734         int_blocks = _multi_blockify(items_dict['IntBlock'])
#    1735         blocks.extend(int_blocks)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in _multi_blockify(tuples, dtype)
#    1818
# -> 1819         values, placement = _stack_arrays(list(tup_block), dtype)
#    1820
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in _stack_arrays(tuples, dtype)
#    1862     for i, arr in enumerate(arrays):
# -> 1863         stacked[i] = _asarray_compat(arr)
#    1864
#
# ValueError: could not broadcast input array from shape (2) into shape (3)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-438-fabc382f59ef> in <module>
# ----> 1 grp.agg(lambda x: test_lambda(x))
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, arg, *args, **kwargs)
#    1313     @Appender(_shared_docs['aggregate'])
#    1314     def aggregate(self, arg, *args, **kwargs):
# -> 1315         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    1316
#    1317     agg = aggregate
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, arg, *args, **kwargs)
#     204                         name=self._selected_obj.columns.name)
#     205                 except Exception:
# --> 206                     result = self._aggregate_generic(arg, *args, **kwargs)
#     207
#     208         if not self.as_index:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _aggregate_generic(self, func, *args, **kwargs)
#     239                     result[name] = data.apply(wrapper, axis=axis)
#     240
# --> 241         return self._wrap_generic_output(result, obj)
#     242
#     243     def _wrap_aggregated_output(self, output, names=None):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _wrap_generic_output(self, result, obj)
#    1352         if self.axis == 0:
#    1353             return DataFrame(result, index=obj.columns,
# -> 1354                              columns=result_index).T
#    1355         else:
#    1356             return DataFrame(result, index=obj.index,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      59     axes = [ensure_index(columns), index]
#      60
# ---> 61     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      62
#      63
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1669         return mgr
#    1670     except ValueError as e:
# -> 1671         construction_error(len(arrays), arrays[0].shape, axes, e)
#    1672
#    1673
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in construction_error(tot_items, block_shape, axes, e)
#    1689         raise ValueError("Empty data passed with indices specified.")
#    1690     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 1691         passed, implied))
#    1692
#    1693
#
# ValueError: Shape of passed values is (3, 6), indices imply (18, 6)

# %%
table = dynamodb.Table('job_task')

user_id='d65cb4f0-8eb7-11e9-b024-39da2a204b63'
job_id = '195795f0-9137-11e9-8c1d-9de473423f0e'
fe = Key('job_id').eq(job_id)
pe = "job_id"
resp = table.scan( FilterExpression = fe)['Items']
#job_cols = ['id','load_id','title']
#all_jobs.merge(pd.DataFrame(resp)[job_cols],how = 'left',left_on='job_id',right_on = 'id')

df = pd.DataFrame(resp).sort_values(by = 'id').reset_index()
num_stops = len(df)
df['stop']= df.index+1
df
# Out:
#    index              address          city  \
# 0      2  206 Springfield Ave        Newark
# 1      1      123 Main street  Philadelphia
# 2      0     600 N Charles St     Baltimore
#
#                              created_by     created_dt dispatch_instruction  \
# 0  d65cb4f0-8eb7-11e9-b024-39da2a204b63  1560800144627                    1
# 1  d65cb4f0-8eb7-11e9-b024-39da2a204b63  1560800144627                    2
# 2  d65cb4f0-8eb7-11e9-b024-39da2a204b63  1560800144627                    2
#
#                                      id  is_completed  \
# 0  195d1430-9137-11e9-8c1d-9de473423f0e         False
# 1  195d1431-9137-11e9-8c1d-9de473423f0e         False
# 2  195d1432-9137-11e9-8c1d-9de473423f0e         False
#
#                                  job_id    modified_dt state  stop
# 0  195795f0-9137-11e9-8c1d-9de473423f0e  1560800144627    NJ     1
# 1  195795f0-9137-11e9-8c1d-9de473423f0e  1560800144627    PA     2
# 2  195795f0-9137-11e9-8c1d-9de473423f0e  1560800144627    MD     3

# %%
df
# Out:
#            address      city                            created_by  \
# 0  9 Ten Broeck Pl    Albany  d65cb4f0-8eb7-11e9-b024-39da2a204b63
# 1      123 Main St  Columbus  d65cb4f0-8eb7-11e9-b024-39da2a204b63
# 1   123 E Broadway  New York  d65cb4f0-8eb7-11e9-b024-39da2a204b63
# 0  123 Main Street  Columbus  d65cb4f0-8eb7-11e9-b024-39da2a204b63
#
#       created_dt dispatch_instruction                                    id  \
# 0  1560545958106                    1  466403a0-8ee7-11e9-8c1d-9de473423f0e
# 1  1560545958106                    2  466403a1-8ee7-11e9-8c1d-9de473423f0e
# 1  1560545326573                    1  cdf7b9d0-8ee5-11e9-8c1d-9de473423f0e
# 0  1560545326573                    2  cdf7b9d1-8ee5-11e9-8c1d-9de473423f0e
#
#    is_completed                                job_id    modified_dt state  \
# 0         False  465e8560-8ee7-11e9-8c1d-9de473423f0e  1560545958106    NY
# 1         False  465e8560-8ee7-11e9-8c1d-9de473423f0e  1560545958106    OH
# 1         False  cdf21480-8ee5-11e9-8c1d-9de473423f0e  1560545326573    NY
# 0         False  cdf21480-8ee5-11e9-8c1d-9de473423f0e  1560545326573    OH
#
#          lat        lon     lat_st     lon_st
# 0  42.658293 -73.751163        NaN        NaN
# 1  39.955681 -83.002757  42.658293 -73.751163
# 1  40.734749 -73.990611        NaN        NaN
# 0  39.955681 -83.002757  40.734749 -73.990611

# %%
all_jobs
# Out:
# Empty DataFrame
# Columns: []
# Index: []
